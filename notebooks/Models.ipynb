# %% [markdown]
# <a href="https://colab.research.google.com/github/wastb/KIAM-Week0-Challenge/blob/task-1/notebooks/Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Google Colab Folder/KIAM-Week4/data/train.csv')
# Out:
# <ipython-input-13-d1e59fd6461c>:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Google Colab Folder/KIAM-Week4/data/train.csv')
