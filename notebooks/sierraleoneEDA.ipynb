# %%
#Import data
import pandas as pd

import sys
sys.path.append("../src")
from preprocessing import view_data as vw
from datacleaning import process_data
from univariateanalysis import plot_data as plot
from zscore import outliers
from bivariateanalysis import pairplots
from multivariateanalysis import monthly_patterns, hourly_patterns,cleaning_effect,wind_rose, relative_humidity_effect, bubble_chart

#dataimprt
benin_data = pd.read_csv('../data/sierraleone-bumbuna.csv')

#Pre processing
vw(benin_data)

#Cleaned data null columns removed, negative values changed 
cleaned_data = process_data(benin_data)

#univariate analysis
plot(cleaned_data)

#zscore calculated and outliers replaced with mean
outliersreplaced = outliers(cleaned_data)

#bivariate analysis between different features
pairplots(outliersreplaced)

#multivariate analysis
monthly_patterns(outliersreplaced)
hourly_patterns(outliersreplaced)
cleaning_effect(outliersreplaced)
wind_rose(outliersreplaced)
relative_humidity_effect(outliersreplaced)
bubble_chart(outliersreplaced)
# Out:
# Data Overview:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 3      0.0  0.0      0.0  1002         0            0.1   22.3   22.6
# 4      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# ...
